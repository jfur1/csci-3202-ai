# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 

import random 

# Number of individuals in each generation 
POPULATION_SIZE = 100

# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated 
TARGET = "To be or not to be."

class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness() 

    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 

    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 

    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''

        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

            # random probability 
            prob = random.random() 

            # if prob is less than 0.45, insert gene 
            # from parent 1 
            if prob < 0.45: 
                child_chromosome.append(gp1) 

            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 

            # otherwise insert random gene(mutate), 
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 

        # create new Individual(offspring) using 
        # generated chromosome for offspring 
        return Individual(child_chromosome) 

    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 

# Driver code 
def main(): 
    global POPULATION_SIZE 

    #current generation 
    generation = 1

    found = False
    population = [] 

    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 

    while not found: 

        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 

        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break

        # Otherwise generate new offsprings for new generation 
        new_generation = [] 

        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 

        # From 50% of fittest population, Individuals 
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 

        population = new_generation 

        print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

        generation += 1


    print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: !wADaI?q
# w9E}tF=6e8	Fitness: 17
# Generation: 2	String: !wADaI?q
# w9E}tF=6e8	Fitness: 17
# Generation: 3	String: tj=6oX%2g@Pv /H 0eD	Fitness: 16
# Generation: 4	String:  ( bHp14_jHv W 9bR3	Fitness: 15
# Generation: 5	String: -orAmX5hr"?t %H ce;	Fitness: 14
# Generation: 6	String: P(Abop14_@=c tF bek	Fitness: 13
# Generation: 7	String: U(Nb7poP 4ot Nc NeH	Fitness: 11
# Generation: 8	String: U(Nb7poP 4ot Nc NeH	Fitness: 11
# Generation: 9	String: UhQb7doD not N  NeH	Fitness: 10
# Generation: 10	String: Poqb
# poJ K9t tF beD	Fitness: 9
# Generation: 11	String: Poqb
# poJ K9t tF beD	Fitness: 9
# Generation: 12	String: Poqb
# poJ K9t tF beD	Fitness: 9
# Generation: 13	String: 4o b$2omqnot t  0e 	Fitness: 8
# Generation: 14	String: Po bndo1 not s; beM	Fitness: 7
# Generation: 15	String: no be o4 69t tF beD	Fitness: 6
# Generation: 16	String: no be o4 69t tF beD	Fitness: 6
# Generation: 17	String: no be o4 69t tF beD	Fitness: 6
# Generation: 18	String: no be oY nyt th beH	Fitness: 5
# Generation: 19	String: no be oY nyt th beH	Fitness: 5
# Generation: 20	String: no be oY nyt th beH	Fitness: 5
# Generation: 21	String: no be oY nyt th beH	Fitness: 5
# Generation: 22	String: no be oY nyt th beH	Fitness: 5
# Generation: 23	String: no be oY nyt th beH	Fitness: 5
# Generation: 24	String: ;o be oY not tF beD	Fitness: 4
# Generation: 25	String: ;o be oY not tF beD	Fitness: 4
# Generation: 26	String: ;o be oY not tF beD	Fitness: 4
# Generation: 27	String: ;o be oY not tF beD	Fitness: 4
# Generation: 28	String: ;o be oY not tF beD	Fitness: 4
# Generation: 29	String: ;o be oY not tF beD	Fitness: 4
# Generation: 30	String: Qo be or not tI beD	Fitness: 3
# Generation: 31	String: Qo be or not tI beD	Fitness: 3
# Generation: 32	String: Qo be or not tI beD	Fitness: 3
# Generation: 33	String: Qo be or not tI beD	Fitness: 3
# Generation: 34	String: Qo be or not tI beD	Fitness: 3
# Generation: 35	String: Qo be or not tI beD	Fitness: 3
# Generation: 36	String: Qo be or not tI beD	Fitness: 3
# Generation: 37	String: Qo be or not tI beD	Fitness: 3
# Generation: 38	String: Qo be or not tI beD	Fitness: 3
# Generation: 39	String: Qo be or not tI beD	Fitness: 3
# Generation: 40	String: Qo be or not tI beD	Fitness: 3
# Generation: 41	String: Qo be or not tI beD	Fitness: 3
# Generation: 42	String: Qo be or not tI beD	Fitness: 3
# Generation: 43	String: Qo be or not tI beD	Fitness: 3
# Generation: 44	String: Qo be or not tI beD	Fitness: 3
# Generation: 45	String: Qo be or not tI beD	Fitness: 3
# Generation: 46	String: Qo be or not tI beD	Fitness: 3
# Generation: 47	String: Qo be or not tI beD	Fitness: 3
# Generation: 48	String: Qo be or not tI beD	Fitness: 3
# Generation: 49	String: Qo be or not tI beD	Fitness: 3
# Generation: 50	String: Qo be or not tI beD	Fitness: 3
# Generation: 51	String: Qo be or not tI beD	Fitness: 3
# Generation: 52	String: Qo be or not tI beD	Fitness: 3
# Generation: 53	String: Qo be or not tI beD	Fitness: 3
# Generation: 54	String: Qo be or not tI beD	Fitness: 3
# Generation: 55	String: Qo be or not tI beD	Fitness: 3
# Generation: 56	String: Qo be or not tI beD	Fitness: 3
# Generation: 57	String: Qo be or not tI beD	Fitness: 3
# Generation: 58	String: Qo be or not tI beD	Fitness: 3
# Generation: 59	String: Qo be or not tI beD	Fitness: 3
# Generation: 60	String: Qo be or not tI beD	Fitness: 3
# Generation: 61	String: Qo be or not tI beD	Fitness: 3
# Generation: 62	String: Qo be or not tI beD	Fitness: 3
# Generation: 63	String: Qo be or not tI beD	Fitness: 3
# Generation: 64	String: Qo be or not tI beD	Fitness: 3
# Generation: 65	String: Qo be or not tI beD	Fitness: 3
# Generation: 66	String: Qo be or not tI beD	Fitness: 3
# Generation: 67	String: Qo be or not tI beD	Fitness: 3
# Generation: 68	String: Qo be or not tI beD	Fitness: 3
# Generation: 69	String: Qo be or not tI beD	Fitness: 3
# Generation: 70	String: Qo be or not tI beD	Fitness: 3
# Generation: 71	String: Bo be or not ta be.	Fitness: 2
# Generation: 72	String: Bo be or not ta be.	Fitness: 2
# Generation: 73	String: Bo be or not ta be.	Fitness: 2
# Generation: 74	String: Bo be or not ta be.	Fitness: 2
# Generation: 75	String: Bo be or not ta be.	Fitness: 2
# Generation: 76	String: Bo be or not ta be.	Fitness: 2
# Generation: 77	String: Bo be or not ta be.	Fitness: 2
# Generation: 78	String: Bo be or not ta be.	Fitness: 2
# Generation: 79	String: Bo be or not ta be.	Fitness: 2
# Generation: 80	String: Bo be or not ta be.	Fitness: 2
# Generation: 81	String: Bo be or not ta be.	Fitness: 2
# Generation: 82	String: To be or not ta be.	Fitness: 1
# Generation: 83	String: To be or not ta be.	Fitness: 1
# Generation: 84	String: To be or not ta be.	Fitness: 1
# Generation: 85	String: To be or not ta be.	Fitness: 1
# Generation: 86	String: To be or not ta be.	Fitness: 1
# Generation: 87	String: To be or not ta be.	Fitness: 1
# Generation: 88	String: To be or not ta be.	Fitness: 1
# Generation: 89	String: To be or not ta be.	Fitness: 1
# Generation: 90	String: To be or not ta be.	Fitness: 1
# Generation: 91	String: To be or not ta be.	Fitness: 1
# Generation: 92	String: To be or not ta be.	Fitness: 1
# Generation: 93	String: To be or not ta be.	Fitness: 1
# Generation: 94	String: To be or not ta be.	Fitness: 1
# Generation: 95	String: To be or not ta be.	Fitness: 1
# Generation: 96	String: To be or not ta be.	Fitness: 1
# Generation: 97	String: To be or not ta be.	Fitness: 1
# Generation: 98	String: To be or not ta be.	Fitness: 1
# Generation: 99	String: To be or not ta be.	Fitness: 1
# Generation: 100	String: To be or not ta be.	Fitness: 1
# Generation: 101	String: To be or not ta be.	Fitness: 1
# Generation: 102	String: To be or not ta be.	Fitness: 1
# Generation: 103	String: To be or not ta be.	Fitness: 1
# Generation: 104	String: To be or not ta be.	Fitness: 1
# Generation: 105	String: To be or not ta be.	Fitness: 1
# Generation: 106	String: To be or not ta be.	Fitness: 1
# Generation: 107	String: To be or not ta be.	Fitness: 1
# Generation: 108	String: To be or not ta be.	Fitness: 1
# Generation: 109	String: To be or not ta be.	Fitness: 1
# Generation: 110	String: To be or not ta be.	Fitness: 1
# Generation: 111	String: To be or not ta be.	Fitness: 1
# Generation: 112	String: To be or not ta be.	Fitness: 1
# Generation: 113	String: To be or not ta be.	Fitness: 1
# Generation: 114	String: To be or not ta be.	Fitness: 1
# Generation: 115	String: To be or not ta be.	Fitness: 1
# Generation: 116	String: To be or not ta be.	Fitness: 1
# Generation: 117	String: To be or not ta be.	Fitness: 1
# Generation: 118	String: To be or not ta be.	Fitness: 1
# Generation: 119	String: To be or not ta be.	Fitness: 1
# Generation: 120	String: To be or not ta be.	Fitness: 1
# Generation: 121	String: To be or not ta be.	Fitness: 1
# Generation: 122	String: To be or not ta be.	Fitness: 1
# Generation: 123	String: To be or not ta be.	Fitness: 1
# Generation: 124	String: To be or not ta be.	Fitness: 1
# Generation: 125	String: To be or not ta be.	Fitness: 1
# Generation: 126	String: To be or not ta be.	Fitness: 1
# Generation: 127	String: To be or not ta be.	Fitness: 1
# Generation: 128	String: To be or not ta be.	Fitness: 1
# Generation: 129	String: To be or not ta be.	Fitness: 1
# Generation: 130	String: To be or not ta be.	Fitness: 1
# Generation: 131	String: To be or not ta be.	Fitness: 1
# Generation: 132	String: To be or not ta be.	Fitness: 1
# Generation: 133	String: To be or not ta be.	Fitness: 1
# Generation: 134	String: To be or not ta be.	Fitness: 1
# Generation: 135	String: To be or not ta be.	Fitness: 1
# Generation: 136	String: To be or not ta be.	Fitness: 1
# Generation: 137	String: To be or not ta be.	Fitness: 1
# Generation: 138	String: To be or not ta be.	Fitness: 1
# Generation: 139	String: To be or not ta be.	Fitness: 1
# Generation: 140	String: To be or not ta be.	Fitness: 1
# Generation: 141	String: To be or not ta be.	Fitness: 1
# Generation: 142	String: To be or not ta be.	Fitness: 1
# Generation: 143	String: To be or not ta be.	Fitness: 1
# Generation: 144	String: To be or not ta be.	Fitness: 1
# Generation: 145	String: To be or not ta be.	Fitness: 1
# Generation: 146	String: To be or not ta be.	Fitness: 1
# Generation: 147	String: To be or not ta be.	Fitness: 1
# Generation: 148	String: To be or not ta be.	Fitness: 1
# Generation: 149	String: To be or not ta be.	Fitness: 1
# Generation: 150	String: To be or not ta be.	Fitness: 1
# Generation: 151	String: To be or not ta be.	Fitness: 1
# Generation: 152	String: To be or not ta be.	Fitness: 1
# Generation: 153	String: To be or not ta be.	Fitness: 1
# Generation: 154	String: To be or not to be.	Fitness: 0
